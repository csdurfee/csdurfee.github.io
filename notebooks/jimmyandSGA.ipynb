# %%
from io import StringIO
import pandas as pd

# %%
x = """
Name	Free throw attempts	FTr	FTr+	PPG
Shai Gilgeous-Alexander	167	0.465	164	32.2
Luka Dončić	150	0.551	194	34.5
Deni Avdija	143	0.472	166	24.9
Devin Booker	141	0.416	147	26.4
James Harden	139	0.488	172	27.8
Franz Wagner	136	0.471	166	23
Giannis Antetokounmpo	132	0.532	188	31.2
Jimmy Butler	132	0.667	235	19.9
Pascal Siakam	130	0.444	156	24.8
Tyrese Maxey	125	0.334	118	33
Nikola Jokić	116	0.395	139	29.6

"""

# %%
foo = pd.read_csv(StringIO(x), delimiter="\t")

# %%
print(foo.to_markdown())
# Out:
# |    | Name                    |   Free throw attempts |   FTr |   FTr+ |   PPG |
# |---:|:------------------------|----------------------:|------:|-------:|------:|
# |  0 | Shai Gilgeous-Alexander |                   167 | 0.465 |    164 |  32.2 |
# |  1 | Luka Dončić             |                   150 | 0.551 |    194 |  34.5 |
# |  2 | Deni Avdija             |                   143 | 0.472 |    166 |  24.9 |
# |  3 | Devin Booker            |                   141 | 0.416 |    147 |  26.4 |
# |  4 | James Harden            |                   139 | 0.488 |    172 |  27.8 |
# |  5 | Franz Wagner            |                   136 | 0.471 |    166 |  23   |
# |  6 | Giannis Antetokounmpo   |                   132 | 0.532 |    188 |  31.2 |
# |  7 | Jimmy Butler            |                   132 | 0.667 |    235 |  19.9 |
# |  8 | Pascal Siakam           |                   130 | 0.444 |    156 |  24.8 |
# |  9 | Tyrese Maxey            |                   125 | 0.334 |    118 |  33   |
# | 10 | Nikola Jokić            |                   116 | 0.395 |    139 |  29.6 |
